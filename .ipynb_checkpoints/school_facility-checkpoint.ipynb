# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("education_data.csv", encoding="latin-1")
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20144\2292165300.py:1: DtypeWarning: Columns (0: improved_water_supply, 1: improved_sanitation, 2: phcn_electricity) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("education_data.csv", encoding="latin-1")
#                            facility_name  \
# 0                              CPS SWALI
# 1                     NANA Basic Academy
# 2            L.E.A Primary School Pabeyi
# 3             L.E.A.PrimarySchoolPagadna
# 4                        Syflora Academy
# ...                                  ...
# 98662             Liberty Primary School
# 98663              Anfani Primary School
# 98664               OLUMAWU BASIC SCHOOL
# 98665                   UBE Akudu Karreh
# 98666  Government Pry School Efut Ibonda
#
#                               facility_type_display improved_water_supply  \
# 0                               Primary school only                  True
# ...

# %%
df.head(10)
# Out:
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
# 5           Nomadic Paiko Kore                           Primary school only
# 6                 Nomadic Jayi                           Primary school only
# 7              Nomadic Kutunku                           Primary school only
# 8       Bargada Primary School                           Primary school only
# 9          Macbeth Intl School  Primary and Junior Secondary school combined
#
#   improved_water_supply improved_sanitation chalkboard_each_classroom_yn  \
# ...

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
#        'community', 'ward', 'management', 'sector', 'formhub_photo_id', 'gps',
#        'survey_id', 'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
df.shape
# Out:
# (98667, 28)

# %%
df.isnull().sum()
# Out:
# facility_name                    215
# facility_type_display            903
# improved_water_supply            279
# improved_sanitation              297
# chalkboard_each_classroom_yn    2161
# num_tchrs_with_nce              3530
# num_tchr_full_time              2164
# num_students_total              5262
# num_classrms_total              3292
# phcn_electricity                 277
# num_toilets_total               2962
# num_students_male               4375
# num_students_female             4346
# num_tchrs_male                  3680
# num_tchrs_female                3319
# date_of_survey                     0
# education_type                   221
# facility_id                        0
# community                        238
# ward                             771
# management                      1223
# sector                             0
# formhub_photo_id                   0
# gps                                0
# survey_id                          0
# ...

# %%
df.dtypes
# Out:
# facility_name                       str
# facility_type_display               str
# improved_water_supply            object
# improved_sanitation              object
# chalkboard_each_classroom_yn     object
# num_tchrs_with_nce              float64
# num_tchr_full_time              float64
# num_students_total              float64
# num_classrms_total              float64
# phcn_electricity                 object
# num_toilets_total               float64
# num_students_male               float64
# num_students_female             float64
# num_tchrs_male                  float64
# num_tchrs_female                float64
# date_of_survey                      str
# education_type                      str
# facility_id                         str
# community                           str
# ward                                str
# management                          str
# sector                              str
# formhub_photo_id                    str
# ...

# %%
#working on facility_name

df["facility_name"].unique()
# Out:
# <StringArray>
# [                        'CPS SWALI',                'NANA Basic Academy',
#        'L.E.A Primary School Pabeyi',        'L.E.A.PrimarySchoolPagadna',
#                    'Syflora Academy',                'Nomadic Paiko Kore',
#                       'Nomadic Jayi',                   'Nomadic Kutunku',
#             'Bargada Primary School',               'Macbeth Intl School',
#  ...
#                           'JSS Wako',             'Nasara Baptist School',
#   'JUNIOR SECONDARY SCHOOL NYANYA 2',              'Wurwa Nomadic School',
#         'UBE PRIMARY SCHOOL EVATURU',            'Liberty Primary School',
#              'Anfani Primary School',              'OLUMAWU BASIC SCHOOL',
#                   'UBE Akudu Karreh', 'Government Pry School Efut Ibonda']
# Length: 92500, dtype: str

# %%
df["facility_name"] = df["facility_name"].str.strip()
df["facility_name"] = df["facility_name"].str.replace(r"\s+", " ", regex=True)
df["facility_name"] = df["facility_name"].replace(
    ["nan", "NaN", "None", ""], np.nan
)

# %%
df["facility_name"].tolist()
# Out:
# ['CPS SWALI',
#  'NANA Basic Academy',
#  'L.E.A Primary School Pabeyi',
#  'L.E.A.PrimarySchoolPagadna',
#  'Syflora Academy',
#  'Nomadic Paiko Kore',
#  'Nomadic Jayi',
#  'Nomadic Kutunku',
#  'Bargada Primary School',
#  'Macbeth Intl School',
#  'Kel Rose Academy',
#  'Ideal Nursery/Primary/Junior Secodary School',
#  'Golden Hope Academy',
#  'Fely Ben Intl School',
#  'Divine Wisdom Academy',
#  'Catherina Intl Academy',
#  'Ambassadors Nur and Primary School',
#  'Patriot Academy Nursery And Primary School',
#  'First Baptist Nursery & Primary School',
#  'PCN Primary school',
#  'Pcn primary school',
#  'PCN primary school',
#  'ST. COLMAN PRIM. SCH. UTUGWANG',
#  'UPE PRIM SCH. UKUTIA',
#  'GOVT. PRIM SCH. UKPIRINYI',
#  'Ojojo Primary School Ã¢Â\x80Â\x98A & BÃ¢Â\x80Â\x98',
#  'UPE Okwukwoetere Emohua',
#  'State school 1. Rumuewhor',
#  'State School 11 Ubimini',
#  'State School 1 Ubimini',
#  'State School Okporowo Ogbakiri',
#  'State School 3 Ibaa',
# ...

# %%
#working on facility_type_display

df["facility_type_display"].unique()
# Out:
# <StringArray>
# [                                 'Primary school only',
#          'Primary and Junior Secondary school combined',
#  'Primary, Junior and Senior Secondary school combined',
#                'Information not available / Don't know',
#                          'Junior Secondary school only',
#           'Junior and Senior Secondary school combined',
#               'Pre-primary and Primary school combined',
#                                                     nan,
#                                          'Primary Only',
#                               'Pre-primary and Primary',
#                 'Primary, Junior, and Senior Secondary',
#                       'Adult, Vocational, or Technical',
#                           'Junior and Senior Secondary',
#                                 'Junior Secondary Only',
#                          'Primary and Junior Secondary',
#                                      'Pre-primary Only',
# ...

# %%
df["facility_type_display"].value_counts()
# Out:
# facility_type_display
# Primary Only                                            28308
# Pre-primary and Primary                                 18847
# Primary school only                                     15153
# Pre-primary and Primary school combined                 10840
# Junior Secondary Only                                    5276
# Junior and Senior Secondary                              5216
# Junior and Senior Secondary school combined              4122
# Junior Secondary school only                             1922
# Pre-primary Only                                         1909
# Senior Secondary Only                                    1476
# Primary, Junior, and Senior Secondary                     969
# Primary and Junior Secondary                              946
# Primary and Junior Secondary school combined              912
# Information not available / Don't know                    800
# Primary, Junior and Senior Secondary school combined      763
# ...

# %%
df["facility_type_display"] = df["facility_type_display"].str.strip()
df["facility_type_display"] = df["facility_type_display"].str.replace(r"\s+", " ", regex=True)
df["facility_type_display"] = df["facility_type_display"].replace(
    ["nan", "NaN", "None", ""], np.nan
)
df["facility_type_display"] = df["facility_type_display"].replace("Information not available / Don't know" , np.nan)

# %%
df.head()
# Out:
#                  facility_name                         facility_type_display  \
# 0                    CPS SWALI                           Primary school only
# 1           NANA Basic Academy  Primary and Junior Secondary school combined
# 2  L.E.A Primary School Pabeyi                           Primary school only
# 3   L.E.A.PrimarySchoolPagadna                           Primary school only
# 4              Syflora Academy                           Primary school only
#
#   improved_water_supply improved_sanitation chalkboard_each_classroom_yn  \
# 0                  True                True                        False
# 1                 False               False                          NaN
# 2                  True                True                        False
# 3                 False                True                        False
# 4                 False                True                         True
#
# ...

# %%
#working on improved_water_supply

df["improved_water_supply"].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
df["improved_water_supply"].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
# df["improved_water_supply"] = (
#     df["improved_water_supply"]
#     .str.strip()
#     .str.replace(r"\s+", " ", regex=True)
#     .replace(["nan", "NaN", "None", ""], np.nan)
# )
# df["improved_water_supply"] = df["improved_water_supply"].astype(bool)

# %%
df["improved_water_supply"] = (
    df["improved_water_supply"]
    .replace(["nan", "NaN", "None", ""], np.nan)
)
df["improved_water_supply"] = df["improved_water_supply"].astype(bool)

# %%
df["improved_water_supply"].unique()
# Out:
# array([ True, False])

# %%
df["improved_water_supply"].value_counts()
# Out:
# improved_water_supply
# False    60954
# True     37713
# Name: count, dtype: int64

# %%
#working with improved_sanitation

df["improved_sanitation"].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
df["improved_sanitation"] = (
    df["improved_sanitation"]
    .replace(["nan", "NaN", "None", ""], np.nan)
)
df["improved_sanitation"] = df["improved_sanitation"].astype(bool)

# %%
df["improved_sanitation"].unique()
# Out:
# array([ True, False])

# %%
#working with chalkboard_each_classroom_yn

df["chalkboard_each_classroom_yn"].unique()
# Out:
# array([False, nan, True], dtype=object)

# %%
df["chalkboard_each_classroom_yn"] = (
    df["chalkboard_each_classroom_yn"]
    .replace(["nan", "NaN", "None", ""], np.nan)
)
df["chalkboard_each_classroom_yn"] = df["chalkboard_each_classroom_yn"].astype(bool)

# %%
df["chalkboard_each_classroom_yn"].unique()
# Out:
# array([False,  True])

# %%
# working on num_tchrs_with_nce

df["num_tchrs_with_nce"].unique()
# Out:
# array([  9.,  nan,   4.,   7.,   3.,  16.,   6.,  12.,  10.,   2.,  25.,
#         14.,  27.,  19.,   8.,  20.,   1.,  15.,   0.,  18.,  33.,   5.,
#         13.,  30.,  29.,  32.,  11.,  44.,  43.,  17.,  40.,  21.,  22.,
#         24.,  28.,  42.,  49.,  52.,  35.,  31.,  55.,  23.,  67.,  66.,
#         50.,  39.,  96.,  37.,  41.,  79.,  46.,  38.,  65.,  56.,  36.,
#         48.,  34.,  26.,  60.,  59.,  71.,  51.,  98.,  86.,  75.,  76.,
#         73.,  92.,  84.,  47.,  80.,  54.,  69.,  45.,  58.,  57.,  62.,
#         63.,  83.,  64.,  68.,  74.,  53.,  90.,  77.,  70.,  89.,  97.,
#         61.,  91.,  72.,  94.,  95.,  78.,  82.,  85.,  93., 100.,  81.,
#         99.])

# %%
#working on num_tchr_full_time

df["num_tchr_full_time"].unique()
# Out:
# array([  9.,  nan,  11.,   5.,   8.,   6.,   4.,  10.,  16.,  35.,  15.,
#         31.,  14.,  30.,  19.,   7.,  33.,  13.,   2.,   3.,  22.,  18.,
#         25.,  51.,  21.,  26.,  17.,   0.,  32.,  45.,  12.,  44.,  72.,
#         43.,  20.,  46.,  40.,  47.,  38.,  29.,  27.,  34.,  49.,  28.,
#         64.,  61.,  37.,  39.,  58.,   1.,  36., 130., 129.,  50.,  59.,
#         23.,  24.,  67.,  41.,  68., 127., 125.,  42., 104.,  79.,  65.,
#         56.,  48., 107.,  52.,  62., 133.,  55.,  71.,  60., 126.,  73.,
#         66.,  69.,  95., 400.,  98.,  89., 108.,  96.,  75.,  53.,  57.,
#         76.,  92.,  84., 380.,  80.,  54., 119.,  74.,  77.,  97.,  63.,
#        625., 154., 180.,  81., 118.,  93.,  90.,  70., 120., 250., 300.,
#         91., 144., 109., 100., 156., 102.,  83., 124., 840., 326., 113.,
#        101., 464., 199.,  88.,  87., 467., 132., 134.,  86., 164., 260.,
#         78., 121., 489., 201., 122., 172., 106.,  82.,  94., 350., 217.,
# ...

# %%
#working with num_students_total

df["num_students_total"].unique()
# Out:
# array([ 776.,   nan,  283., ..., 1785., 1952., 1943.], shape=(2182,))

# %%
#working with num_classrms_total

df["num_classrms_total"].unique()
# Out:
# array([ 12.,  nan,   9.,   7.,  10.,   6.,  14.,   8.,  29.,  13.,  20.,
#         34.,  25.,   5.,   4.,   3.,   2.,  11.,  18.,  15.,  16.,   1.,
#          0.,  22.,  17.,  21.,  24.,  40.,  19.,  23.,  44.,  64.,  27.,
#         42.,  31.,  30.,  37.,  47.,  26.,  45.,  50.,  60.,  48.,  35.,
#        106.,  41.,  32.,  33.,  56.,  28.,  36.,  54.,  53.,  46.,  51.,
#         43.,  38.,  39.,  74., 514.,  58.,  98.,  57.,  52.,  67.,  72.,
#         65., 120.,  90.,  82.,  55.,  86.,  70.,  68., 150., 105.,  80.,
#         76., 114., 110.,  49.,  66., 165.,  61., 407., 104., 185.,  89.,
#        100.,  75., 455., 112., 339., 135.,  78.,  59.,  69.,  73.,  88.])

# %%
#working with phcn_electricity

df["phcn_electricity"].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
df["phcn_electricity"] = (
    df["phcn_electricity"]
    .replace(["nan", "NaN", "None", ""], np.nan)
)
df["phcn_electricity"] = df["phcn_electricity"].astype(bool)

# %%
df["phcn_electricity"].unique()
# Out:
# array([False,  True])

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
#        'community', 'ward', 'management', 'sector', 'formhub_photo_id', 'gps',
#        'survey_id', 'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
#working with number to toilet total

df["num_toilets_total"].unique()
# Out:
# array([ 21.,   0.,   2.,   4.,  10.,   1.,   6.,   3.,  24.,  14.,   5.,
#         12.,  nan,  13.,   8.,  16.,  11.,   7.,  54.,  18.,  15.,   9.,
#         20.,  17.,  32.,  92.,  30.,  19.,  26., 345.,  27.,  23.,  22.,
#         36.,  25.,  28.,  46.,  41.,  50.,  53.,  43.,  38.,  60.,  85.,
#         70.,  55.,  37.,  65.,  40.,  42., 105.,  35.,  51.,  52., 112.,
#         80.,  62.,  95.,  45.,  76.,  29.,  96.,  48.,  64.,  59.,  31.,
#         56., 120.,  44.,  39., 300.,  34.,  57., 118., 240.,  98.,  67.,
#        200.,  33.,  47., 117.,  75., 140., 223., 202., 116.,  71., 158.,
#        369.,  68., 102.,  74.,  99.,  86., 100.,  58.,  49., 129., 162.,
#        251.,  78.,  77., 103., 132., 418., 239., 303., 315.])

# %%
#working with num_students_male

df["num_students_male"].unique()
# Out:
# array([ 383.,   nan,  185., ..., 2062., 3274., 1144.], shape=(1781,))

# %%
#working with num_students_female

df["num_students_female"].unique()
# Out:
# array([ 393.,   nan,   98., ..., 1732., 2047., 1802.], shape=(1682,))

# %%
#working on num_tchrs_male

df["num_tchrs_male"].unique()
# Out:
# array([  5.,  nan,   9.,   2.,   3.,   7.,   6.,   1.,  15.,   4.,  16.,
#         10.,  13.,   8.,  19.,  26.,  14.,   0.,  44.,  11.,  12.,  27.,
#         18.,  24.,  20.,  21.,  40.,  22.,  17.,  33.,  29.,  58.,  60.,
#         38.,  30.,  23.,  54.,  36.,  43.,  28.,  34.,  32.,  52.,  46.,
#         78.,  25.,  35.,  65.,  49.,  50.,  63.,  47.,  84.,  31.,  41.,
#         71.,  80.,  37.,  82.,  59.,  55.,  42.,  68.,  92.,  51.,  39.,
#         57.,  56.,  48.,  67., 100.,  45.,  75.,  73.,  62.,  53.,  61.,
#         69.,  64.,  81.,  90.,  72.,  85.,  76.,  98.,  66.,  91.,  70.,
#         86.])

# %%
#working on num_tchrs_female

df["num_tchrs_female"].unique()
# Out:
# array([  4.,  nan,   2.,   0.,   6.,   1.,   3.,  10.,   8.,   7.,  20.,
#         27.,  21.,  32.,  17.,  14.,  25.,  19.,   5.,  13.,  43.,  16.,
#         42.,  12.,  15.,  28.,  37.,  11.,  22.,  18.,   9.,  31.,  47.,
#         24.,  26.,  70., 100.,  40.,  29.,  53.,  48.,  46.,  30.,  73.,
#         82.,  35.,  86.,  50.,  23.,  62.,  60.,  54.,  36.,  55.,  39.,
#         34.,  38.,  51.,  44.,  52.,  49.,  56.,  68.,  41.,  57.,  76.,
#         33.,  59.,  65.,  61.,  67.,  45.,  63.,  77.,  89.,  69.,  72.,
#         71.,  74.,  64.,  80.,  66.,  75.,  79.,  81.,  58.,  95.,  78.,
#         99.,  98.,  91.,  88.,  83.,  84.,  90.,  96.,  87.,  85.,  94.,
#         92.])

# %%
#working on date_of_survey

df["date_of_survey"].unique()
# Out:
# <StringArray>
# ['2014-03-04', '2014-05-02', '2014-04-25', '2014-04-21', '2014-04-28',
#  '2014-03-05', '2014-02-27', '2014-02-28', '2014-04-11', '2014-04-09',
#  ...
#  '2014-03-09', '2010-11-27', '2012-07-05', '2012-09-01', '2012-04-20',
#  '2012-05-14', '2012-09-19', '2011-03-06', '2014-07-06', '2014-06-30']
# Length: 361, dtype: str

# %%
df["date_of_survey"] = df["date_of_survey"].replace("nan",np.nan)

# %%
df["date_of_survey"] = pd.to_datetime(df["date_of_survey"] , errors = "coerce")
df["date_of_survey"]
# Out:
# 0       2014-03-04
# 1       2014-05-02
# 2       2014-05-02
# 3       2014-04-25
# 4       2014-04-25
#            ...
# 98662   2014-04-09
# 98663   2014-04-13
# 98664   2014-05-02
# 98665   2014-05-21
# 98666   2014-04-17
# Name: date_of_survey, Length: 98667, dtype: datetime64[us]

# %%
df["date_of_survey"].unique()
# Out:
# <DatetimeArray>
# ['2014-03-04 00:00:00', '2014-05-02 00:00:00', '2014-04-25 00:00:00',
#  '2014-04-21 00:00:00', '2014-04-28 00:00:00', '2014-03-05 00:00:00',
#  '2014-02-27 00:00:00', '2014-02-28 00:00:00', '2014-04-11 00:00:00',
#  '2014-04-09 00:00:00',
#  ...
#  '2014-03-09 00:00:00', '2010-11-27 00:00:00', '2012-07-05 00:00:00',
#  '2012-09-01 00:00:00', '2012-04-20 00:00:00', '2012-05-14 00:00:00',
#  '2012-09-19 00:00:00', '2011-03-06 00:00:00', '2014-07-06 00:00:00',
#  '2014-06-30 00:00:00']
# Length: 361, dtype: datetime64[us]

# %%
#working on education_type

df["education_type"].unique()
# Out:
# <StringArray>
# [   'formal_only',             'dk',     'integrated', 'religious_only',
#     'Formal Only',     'Integrated', 'Religious Only',              nan]
# Length: 8, dtype: str

# %%
df["education_type"] = (
    df["education_type"]
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
    .replace(["nan", "NaN", "None", ""], np.nan)
    .replace({
        "Formal Only":"Formal_only",
        "formal_only":"Formal_only",
        "dk":np.nan,
        "Religious Only":"Religious_only"
    })
    .str.title()
)
df["education_type"].unique()
# Out:
# <StringArray>
# ['Formal_Only', nan, 'Integrated', 'Religious_Only']
# Length: 4, dtype: str

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'facility_id',
#        'community', 'ward', 'management', 'sector', 'formhub_photo_id', 'gps',
#        'survey_id', 'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
#WORKING ON facility_id

df["facility_id"].unique()
# Out:
# <StringArray>
# ['EIRJK', 'ENQHE', 'EDJJK', 'ELOOD', 'EZJOH', 'EULMF', 'EBQPK', 'EOPJV',
#  'EEMRF', 'ELQLC',
#  ...
#  'EGWMY', 'ESEMM', 'TKNHB', 'EXDXL', 'EPWFP', 'EMWBJ', 'EIEMQ', 'EAFKM',
#  'EZLFV', 'EJMDC']
# Length: 98614, dtype: str

# %%
df = df.drop("facility_id", axis=1)

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'community',
#        'ward', 'management', 'sector', 'formhub_photo_id', 'gps', 'survey_id',
#        'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
#working with community

df["community"].unique()
# Out:
# <StringArray>
# [                'Swali',                 'Mpape',                'Pabeyi',
#                'Pagadna',            'Paiko Kore',                  'Jayi',
#                'Kutunku',               'Bargada',               'Byazhin',
#                 'Dawaki',
#  ...
#                'Katbala',            'Rim bwarak',            'Tungar Idi',
#          'UNGUWAR SANDA',                'Wutana',           'Kato bakwai',
#                  'Wurwa',               'EVATURU',         'Akudu Akarreh',
#  'Efut Ibonda Community']
# Length: 58547, dtype: str

# %%
df["community"] = (
    df["community"]
    .str.strip()
    .str.replace(r"\s+", " ", regex=True)
    .replace(["nan", "NaN", "None", ""], np.nan)
    .str.title()
)

# %%
df["community"].unique()
# Out:
# <StringArray>
# [                'Swali',                 'Mpape',                'Pabeyi',
#                'Pagadna',            'Paiko Kore',                  'Jayi',
#                'Kutunku',               'Bargada',               'Byazhin',
#                 'Dawaki',
#  ...
#                'Sakkere',               'Katbala',            'Tungar Idi',
#          'Unguwar Sanda',                'Wutana',           'Kato Bakwai',
#                  'Wurwa',               'Evaturu',         'Akudu Akarreh',
#  'Efut Ibonda Community']
# Length: 52437, dtype: str

# %%
#working on ward

df["ward"].unique()
# Out:
# <StringArray>
# [                   '3',                'Dutse',                 'Dobi',
#                 'Paiko',              'Kutunku',              'Byazhin',
#          'Dutse Alhaji',                'Kubwa',                    nan,
#                     '4',
#  ...
#        'AYETORO WARD 2',     'Oke Odo Obantoko',                'AGADO',
#           'Ekori Anaku',               'BADARI',                 'Raga',
#             'Tube ward', 'Kyola nomadic school',          'Gidan Agwai',
#      'Adiabo Efut Ward']
# Length: 24019, dtype: str

# %%
df = df.drop("ward", axis=1)

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'community',
#        'management', 'sector', 'formhub_photo_id', 'gps', 'survey_id',
#        'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
#working on management

df["management"].unique()
# Out:
# <StringArray>
# ['public', 'private', 'none', 'faith_based', nan]
# Length: 5, dtype: str

# %%
df["management"] = (
    df["management"]
    .str.strip()
    .str.replace(r"\s+"," ",regex=True)
    .replace(["none", "nan"] , np.nan)
    .str.title()
)

df["management"].unique()
# Out:
# <StringArray>
# ['Public', 'Private', nan, 'Faith_Based']
# Length: 4, dtype: str

# %%
#working with sector

df["sector"].unique()
# Out:
# <StringArray>
# ['education']
# Length: 1, dtype: str

# %%
df = df.drop("sector" , axis=1)

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'community',
#        'management', 'formhub_photo_id', 'gps', 'survey_id', 'unique_lga',
#        'latitude', 'longitude'],
#       dtype='str')

# %%
#working on formhub_photo_id

df["formhub_photo_id"].unique()
# Out:
# <StringArray>
# ['1393404015008.jpg', '1396960914896.jpg', '1397575395444.jpg',
#  '1398262573409.jpg', '1396959110576.jpg', '1398330459520.jpg',
#  '1397572115063.jpg', '1398345111978.jpg', '1398340786686.jpg',
#  '1397485980654.jpg',
#  ...
#  '1396617052102.jpg', '1399544804862.jpg', '1396621715486.jpg',
#  '1397474636189.jpg', '1399044041174.jpg', '1396871679634.jpg',
#  '1396966652017.jpg', '1398257399697.jpg', '1394973132370.jpg',
#  '1397642929962.jpg']
# Length: 97927, dtype: str

# %%
df = df.drop("formhub_photo_id", axis=1)

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'community',
#        'management', 'gps', 'survey_id', 'unique_lga', 'latitude',
#        'longitude'],
#       dtype='str')

# %%
#working on gps

df["gps"].unique()
# Out:
# <StringArray>
# [                           '4.91691036 6.27412844 31.5 5.0',
#              '9.140918333333333 7.496761666666667 697.0 4.5',
#                      '9.174855 7.0220616666666675 236.8 5.0',
#              '9.115846666666666 6.962314999999999 216.5 4.4',
#                       '9.141155 7.499665000000001 693.2 4.7',
#                       '8.99146 7.0096750000000005 170.9 5.0',
#              '9.204203333333334 7.015148333333333 271.4 4.5',
#              '8.934686666666666 7.056360000000001 174.9 4.6',
#              '8.921268333333334 6.959628333333335 161.8 4.3',
#                       '9.19196 7.3325966666666655 455.2 3.8',
#  ...
#                '8.59604555 6.9120111 130.10000610351563 5.0',
#               '11.09271129 7.71040839 666.2999877929688 5.0',
#                        '9.028733333333333 7.57186 525.4 4.4',
#              '11.19290112 9.75430421 469.79998779296875 5.0',
#                            '10.45925951 7.8648471 662.0 5.0',
# ...

# %%
df = df.drop("gps" , axis=1)

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'community',
#        'management', 'survey_id', 'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
#working on survey_id

df["survey_id"].unique()
# Out:
# <StringArray>
# ['51885096-65a1-4f1f-8c2a-3b11d9ae40bb',
#  '7f3ea41a-e4cb-41dd-85fc-5fa54c42d09f',
#  '56f2e625-ec43-4c39-97a8-d6379dceefa2',
#  '2932eda8-64b1-4068-8412-3b2e099062fc',
#  'e17acb1e-364a-4a90-9384-0d612bb240c5',
#  '28d8fe5a-7a18-4d17-9f64-7ae095eb1c50',
#  '31381276-73f9-4e30-acde-bec286919256',
#  '76a5fbc9-6723-467a-939d-703a3702ec53',
#  '6bd36fb3-704a-49ad-a96a-b25b24af78d3',
#  '7e344ad8-c442-4138-a869-6ce98794beaa',
#  ...
#  'b91dea7b-d636-4752-969a-72ccb3a761c6',
#  '52c58d7a-b8f3-4a7f-aa4b-625e52d4a163',
#  '9d1845bb-5468-43c2-86c6-ac20b0c51771',
#  '29de53f4-1327-42bc-a43a-920017d4ac03',
#  '17308ccf-1c5e-4025-b640-4644e270448f',
#  '010545d1-8fed-41fe-bcae-c142046a04e3',
#  '5d81b15f-a114-4987-adce-70b67744f3ad',
#  '6d63ceb8-bca5-4702-8313-41944e2d2dbd',
#  'e22ff822-bf51-4a22-81b8-32ba8642b0f7',
#  '68027644-9dad-4c04-b458-95fcd7de1981']
# Length: 98614, dtype: str

# %%
df = df.drop("survey_id", axis=1)

# %%
df.columns
# Out:
# Index(['facility_name', 'facility_type_display', 'improved_water_supply',
#        'improved_sanitation', 'chalkboard_each_classroom_yn',
#        'num_tchrs_with_nce', 'num_tchr_full_time', 'num_students_total',
#        'num_classrms_total', 'phcn_electricity', 'num_toilets_total',
#        'num_students_male', 'num_students_female', 'num_tchrs_male',
#        'num_tchrs_female', 'date_of_survey', 'education_type', 'community',
#        'management', 'unique_lga', 'latitude', 'longitude'],
#       dtype='str')

# %%
#working on unique_lga

df["unique_lga"].tolist()
# Out:
# ['bayelsa_yenagoa',
#  'fct_bwari',
#  'fct_gwagwalada',
#  'fct_gwagwalada',
#  'fct_bwari',
#  'fct_gwagwalada',
#  'fct_gwagwalada',
#  'fct_gwagwalada',
#  'fct_gwagwalada',
#  'fct_bwari',
#  'fct_bwari',
#  'fct_bwari',
#  'fct_bwari',
#  'fct_bwari',
#  'fct_bwari',
#  'fct_bwari',
#  'fct_bwari',
#  'lagos_apapa',
#  'rivers_emuoha',
#  'cross_river_biase',
#  'cross_river_biase',
#  'cross_river_biase',
#  'cross_river_obudu',
#  'cross_river_obudu',
#  'cross_river_obudu',
#  'delta_warri_south',
#  'rivers_emuoha',
#  'rivers_emuoha',
#  'rivers_emuoha',
#  'rivers_emuoha',
#  'rivers_emuoha',
#  'rivers_emuoha',
#  'kaduna_lere',
#  'kaduna_lere',
#  'kaduna_lere',
#  'kaduna_lere',
#  'kaduna_lere',
#  'kaduna_lere',
#  'kaduna_lere',
#  'rivers_oyigbo',
#  'rivers_oyigbo',
#  'rivers_oyigbo',
#  'sokoto_silame',
#  'katsina_bindawa',
#  'katsina_bindawa',
#  'katsina_bindawa',
#  'taraba_gashaka',
#  'kaduna_sanga',
#  'taraba_gashaka',
#  'taraba_gashaka',
# ...

# %%
df["unique_lga"]= (
    df["unique_lga"]
    .str.strip()
    .str.replace(r"\s+"," ",regex=True)
    .replace(["none","nan","NaN","None",""] , np.nan)
    .str.title()
)

df["unique_lga"].unique()
# Out:
# <StringArray>
# [  'Bayelsa_Yenagoa',         'Fct_Bwari',    'Fct_Gwagwalada',
#        'Lagos_Apapa',     'Rivers_Emuoha', 'Cross_River_Biase',
#  'Cross_River_Obudu', 'Delta_Warri_South',       'Kaduna_Lere',
#      'Rivers_Oyigbo',
#  ...
#        'Borno_Dikwa',      'Borno_Damboa',     'Yobe_Damaturu',
#       'Borno_Chibok',       'Yobe_Bosari',         'Borno_Biu',
#         'Yobe_Barde',        'Borno_Bama',  'Borno_Askira_Uba',
#        'Benue_Agatu']
# Length: 773, dtype: str

# %%
#working on latitude

df["latitude"].unique()
# Out:
# array([ 4.91691036,  9.14091833,  9.174855  , ...,  9.071785  ,
#        10.77455242,  5.03017455], shape=(97496,))

# %%
#working on longitude

df["longitude"].unique()
# Out:
# array([6.27412844, 7.49676167, 7.02206167, ..., 7.47780333, 8.36796434,
#        8.2667556 ], shape=(97486,))
